# %%
import numpy as np
import pandas as pd 
import  category_encoders as ce
from sklearn.preprocessing import LabelBinarizer
from sklearn.externals import joblib
from sklearn.preprocessing import OneHotEncoder
# Out:
# C:\Users\saima\Anaconda3\envs\kick\lib\site-packages\sklearn\externals\joblib\__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
data_path = "../data/notebooks/4_merged_data.csv"
df = pd.read_csv(data_path)
df_raw = df.copy()
# Out:
# C:\Users\saima\Anaconda3\envs\kick\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (29) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
target_encoding_cols = ['location_country' , 'currency' , 'category', 'sub_category']

# %%
model_oh = joblib.load('estimators/model_oh.sav')
model_hel = joblib.load('estimators/model_hel.sav')

encoder_oh =  joblib.load('estimators/encoder_oh.sav')
encoder_hel = joblib.load('estimators/encoder_hel.sav')

binarizer =  joblib.load('estimators/encoder_label.sav')

# %%
pred_dic = {
    
 "launched_at":'2019-11-06', 
    "deadline":"2019-12-06", 
    "goal":1000, 
    "sub_category":"comic books", 
    "category":"comics",
    "currency":"GBP", 
    "location_country":"the United Kingdom",
    "blurb":"A multimedia journalistic trip to a culture different than my own in order to explore & document a radically different way of life.",
    "rewards":"[10,20, 50, 250, 500 , 1000 ]",  
    
}

pred_df = {
    "days_to_deadline":[], 
    "goal":[], 
    
    "blurb_length":[],
    
    
    
    "rewards_mean":[], 
    "rewards_median":[], 
    "rewards_variance":[], 
    "rewards_SD":[], 
    "rewards_MIN":[], 
    "rewards_MAX":[], 
    "rewards_NUM":[], 
    
    "launch_year":[], 
    "launch_month":[], 
     "deadline_year":[], 
    "deadline_month":[], 
    
     "location_country":[],
     "currency":[], 

   
    "category":[], 
    "sub_category":[], 
    
    
    
}

# %%
def getMean(x):
    
    lis = eval(x)

    return np.array(lis).mean()

def getMedian(x):
    lis = eval(x)
    return np.median(lis)

def getVariance(x):
    lis = eval(x)
    return np.array(lis).var()


def getSD(x):
    lis = eval(x)
    return np.std(lis)

def getMIN(x):
    lis = eval(x)
    return min(lis)


def getMAX(x):
    lis = eval(x)
    return max(lis)




def getNUM(x):
    lis = eval(x)
    
    return len(lis)

def get_blurb_length(x):
    return len(x)

# %%
pred_df["rewards_mean"].append(getMean(pred_dic['rewards']))
pred_df["rewards_median"].append(getMedian(pred_dic['rewards']))
pred_df["rewards_variance"].append(getVariance(pred_dic['rewards']))
pred_df["rewards_SD"].append(getSD(pred_dic['rewards']))
pred_df["rewards_MIN"].append(getMIN(pred_dic['rewards']))
pred_df["rewards_MAX"].append(getMAX(pred_dic['rewards']))
pred_df["rewards_NUM"].append(getNUM(pred_dic['rewards']))
pred_df['launch_year'].append(pd.to_datetime(pred_dic['launched_at']).year)
pred_df['launch_month'].append(pd.to_datetime(pred_dic['launched_at']).month)
pred_df['deadline_year'].append(pd.to_datetime(pred_dic['deadline']).year)
pred_df['deadline_month'].append(pd.to_datetime(pred_dic['deadline']).month)
pred_df['days_to_deadline'].append((pd.to_datetime(pred_dic['deadline']) - pd.to_datetime(pred_dic['launched_at'])).days)
pred_df['blurb_length'].append(get_blurb_length(pred_dic['blurb']))
pred_df['goal'].append(pred_dic['goal'])
pred_df['category'].append(pred_dic['category'])
pred_df['sub_category'].append(pred_dic['sub_category'])
pred_df['currency'].append(pred_dic['currency'])
pred_df['location_country'].append(pred_dic['location_country'])

# %%
df_pred = pd.DataFrame.from_dict(pred_df )

# %%
def transform_onehot(df , cols , encoder):
    df_temp = pd.DataFrame(encoder.transform(df[cols]) , columns =  [x for sublist in encoder.categories_ for x in sublist])
    df = pd.concat([df , df_temp] , axis=1)
    df_resp = df.copy()
    df_resp.drop(cols , axis=1 , inplace=True)
    return df_resp

# %%
def transform_helmert(df , cols , encoder):
    df_temp = encoder.transform(df[cols])
    df = pd.concat([df , df_temp] , axis=1)
    df_resp = df.copy()
    df_resp.drop(cols , axis=1 , inplace=True)
    return df_resp

# %%
df_pred_oh = transform_onehot(df_pred , target_encoding_cols , encoder_oh)
df_pred_hel = transform_helmert(df_pred , target_encoding_cols , encoder_hel)

# %% [markdown]
# # ELI5

# %%
import eli5
# Out:
# C:\Users\saima\Anaconda3\envs\kick\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\saima\Anaconda3\envs\kick\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# **Required columns are selected based on the features which the user are seeking to tune one's that are excluded are the one's which can not be changed associated with a campaign, for ex after we developed a product we can not change the category it fit's into just because the change would increase the probability of a successful campaign**

# %%
categ_cols =[pred_df['category'][0] , pred_df['sub_category'][0] , pred_df['currency'][0] , pred_df['location_country'][0]]
required_columns = ['blurb_length', 'goal' ,'rewards_variance','rewards_median', 'rewards_SD', 'rewards_MIN', 'rewards_MAX', 'rewards_NUM'
                   ,'days_to_delivery', 'days_to_deadline', 'launch_year', 'deadline_year']
all_cols =required_columns+categ_cols

# %%
def func(x , s):
    return x in required_columns

# %% [markdown]
# ## Model_OH

# %%
eli5.explain_prediction_xgboost(model_oh.get_booster() , df_pred_oh.iloc[0]  , feature_filter=func)
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x000001240D3DBBE0>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='goal', weight=0.6607508453365646, std=None, value=1000.0), FeatureWeight(feature='launch_year', weight=0.36168299739233556, std=None, value=2019.0), FeatureWeight(feature='rewards_NUM', weight=0.0750474074290459, std=None, value=6.0), FeatureWeight(feature='rewards_MIN', weight=0.06692665375817981, std=None, value=10.0), FeatureWeight(feature='rewards_median', weight=0.032422110945231175, std=None, value=150.0), FeatureWeight(feature='rewards_MAX', weight=0.004896203484318187, std=None, value=1000.0)], neg=[FeatureWeight(feature='rewards_variance', weight=-0.1478210271995439, std=None, value=126225.0), FeatureWeight(feature='days_to_deadline', weight=-0.08252784430496198, std=None, value=30.0), FeatureWeight(feature='blurb_length', weight=-0.03176500072222235, std=None, value=131.0), FeatureWeight(feature='deadline_year', weight=-0.006028898960854826, std=None, value=2019.0)], pos_remaining=0, neg_remaining=0), proba=None, score=5.936485150977997, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# **Feature Importance of Model_OH**

# %%
eli5.explain_weights_xgboost(model_oh.get_booster())
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x000001240D3DBBE0>', description='\nXGBoost feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=None, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='games', weight=0.026366925, std=None, value=None), FeatureWeight(feature='web', weight=0.025794176, std=None, value=None), FeatureWeight(feature='shorts', weight=0.02492595, std=None, value=None), FeatureWeight(feature='documentary', weight=0.02456094, std=None, value=None), FeatureWeight(feature="children's books", weight=0.024174174, std=None, value=None), FeatureWeight(feature='accessories', weight=0.02320127, std=None, value=None), FeatureWeight(feature='illustration', weight=0.022133356, std=None, value=None), FeatureWeight(feature='food', weight=0.02204428, std=None, value=None), FeatureWeight(feature='apparel', weight=0.021506244, std=None, value=None), FeatureWeight(feature='rewards_NUM', weight=0.021276709, std=None, value=None), FeatureWeight(feature='video games', weight=0.02033463, std=None, value=None), FeatureWeight(feature='country & folk', weight=0.019864567, std=None, value=None), FeatureWeight(feature='crafts', weight=0.019458357, std=None, value=None), FeatureWeight(feature='fiction', weight=0.01932555, std=None, value=None), FeatureWeight(feature='nonfiction', weight=0.018882578, std=None, value=None), FeatureWeight(feature='product design', weight=0.01749546, std=None, value=None), FeatureWeight(feature='comics', weight=0.016989274, std=None, value=None), FeatureWeight(feature='rock', weight=0.016721854, std=None, value=None), FeatureWeight(feature='comic books', weight=0.01587088, std=None, value=None), FeatureWeight(feature='indie rock', weight=0.015638957, std=None, value=None)], remaining=205), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# ## Model_hel

# %%
eli5.explain_prediction_xgboost(model_hel.get_booster() , df_pred_hel.iloc[0]  , feature_filter=func)
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x000001240D3DBBA8>', description='\nFeatures with largest coefficients.\n\nFeature weights are calculated by following decision paths in trees\nof an ensemble. Each leaf has an output score, and expected scores can also be\nassigned to parent nodes. Contribution of one feature on the decision path\nis how much expected score changes from parent to child. Weights of all \nfeatures sum to the output score of the estimator.\n\nCaveats:\n1. Feature weights just show if the feature contributed positively or\n   negatively to the final score, and does not show how increasing or\n   decreasing the feature value will change the prediction.\n2. In some cases, feature weight can be close to zero for an important feature.\n   For example, in a single tree that computes XOR function, the feature at the\n   top of the tree will have zero weight because expected scores for both\n   branches are equal, so decision at the top feature does not change the\n   expected score. For an ensemble predicting XOR functions it might not be\n   a problem, but it is not reliable if most trees happen to choose the same\n   feature at the top.\n', error=None, method='decision paths', is_regression=True, targets=[TargetExplanation(target='y', feature_weights=FeatureWeights(pos=[FeatureWeight(feature='goal', weight=0.2988563131779584, std=None, value=1000.0), FeatureWeight(feature='launch_year', weight=0.14737957072236524, std=None, value=2019.0), FeatureWeight(feature='deadline_year', weight=0.10884282392753308, std=None, value=2019.0), FeatureWeight(feature='rewards_NUM', weight=0.10875538980159916, std=None, value=6.0), FeatureWeight(feature='rewards_MAX', weight=0.04484014228629488, std=None, value=1000.0)], neg=[FeatureWeight(feature='rewards_variance', weight=-0.1259800890838928, std=None, value=126225.0), FeatureWeight(feature='rewards_MIN', weight=-0.12510915996657543, std=None, value=10.0), FeatureWeight(feature='rewards_median', weight=-0.08440212102216255, std=None, value=150.0), FeatureWeight(feature='days_to_deadline', weight=-0.05202489850904173, std=None, value=30.0), FeatureWeight(feature='blurb_length', weight=-0.005712334751432593, std=None, value=131.0)], pos_remaining=0, neg_remaining=0), proba=None, score=7.727776805257828, weighted_spans=None, heatmap=None)], feature_importances=None, decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# **Feature Importance of Model_Hel**

# %%
eli5.explain_weights_xgboost(model_hel.get_booster())
# Out:
# Explanation(estimator='<xgboost.core.Booster object at 0x000001240D3DBBA8>', description='\nXGBoost feature importances; values are numbers 0 <= x <= 1;\nall values sum to 1.\n', error=None, method='feature importances', is_regression=None, targets=None, feature_importances=FeatureImportances(importances=[FeatureWeight(feature='sub_category_138', weight=0.16744526, std=None, value=None), FeatureWeight(feature='sub_category_137', weight=0.14356998, std=None, value=None), FeatureWeight(feature='sub_category_136', weight=0.06919899, std=None, value=None), FeatureWeight(feature='sub_category_35', weight=0.021638006, std=None, value=None), FeatureWeight(feature='sub_category_20', weight=0.021344021, std=None, value=None), FeatureWeight(feature='sub_category_79', weight=0.02115586, std=None, value=None), FeatureWeight(feature='sub_category_76', weight=0.018995024, std=None, value=None), FeatureWeight(feature='sub_category_40', weight=0.018601337, std=None, value=None), FeatureWeight(feature='sub_category_26', weight=0.018434374, std=None, value=None), FeatureWeight(feature='rewards_NUM', weight=0.01640392, std=None, value=None), FeatureWeight(feature='sub_category_39', weight=0.0158548, std=None, value=None), FeatureWeight(feature='category_12', weight=0.014934146, std=None, value=None), FeatureWeight(feature='sub_category_36', weight=0.014707672, std=None, value=None), FeatureWeight(feature='sub_category_9', weight=0.014415605, std=None, value=None), FeatureWeight(feature='sub_category_84', weight=0.013579383, std=None, value=None), FeatureWeight(feature='sub_category_34', weight=0.012927636, std=None, value=None), FeatureWeight(feature='sub_category_77', weight=0.012030924, std=None, value=None), FeatureWeight(feature='sub_category_128', weight=0.011608683, std=None, value=None), FeatureWeight(feature='category_9', weight=0.0109833125, std=None, value=None), FeatureWeight(feature='sub_category_15', weight=0.010672224, std=None, value=None)], remaining=201), decision_tree=None, highlight_spaces=None, transition_features=None, image=None)

# %% [markdown]
# ### Conclusion
# **We will be using the model with helmert encoding even though variables which are subjected to the encoding become uninterpretable and the reason is variables which are transformed are fixed variables which would not be interpreted any way in our final dashboard.**
